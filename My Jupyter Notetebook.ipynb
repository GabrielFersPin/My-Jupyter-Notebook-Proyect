# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Gabriel Felipe Fernandes Pinheiro__ - Student

# %% [markdown]
# _I'm interested in data science because I'm curious and deal with problems in a creative way as a dynamic environment where you can learn every day something different._

# %% [markdown]
# My code is a simple print on the screen in phyton code.

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Line above horizontal rule
# ***
# Line below horizontal rule

# %% [markdown]
# - Bullet list
#     * Bullet sublist

# %% [markdown]
# | (1,1) | (1,2) | (1,3) |
# | --- | --- | --- |
# | (2,1) | (2,2) | (2,3) |
